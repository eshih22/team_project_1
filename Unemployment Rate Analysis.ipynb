# %%
import requests
import pandas as pd
from config import census_api_key
from config import geoapify_key
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.stats import linregress
import os
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
unemployment18 = Path("csv_data/2018 unemployment.csv")
unemployment19 = Path("csv_data/2019 unemployment.csv")
unemployment20 = Path("csv_data/2020 unemployment.csv")
unemployment21 = Path("csv_data/2021 unemployment.csv")

# %%
unemployment18_df = pd.read_csv(unemployment18)
no_nulls_18_df = unemployment18_df.dropna(how='any')

no_nulls_18_df['Area Name'] = no_nulls_18_df['Area Name'].str.replace(', California', '')
no_nulls_18_df['Area Name'] = no_nulls_18_df['Area Name'].str.replace(' CDP', '')
no_nulls_18_df['Area Name'] = no_nulls_18_df['Area Name'].str.replace(' city', '')
no_nulls_18_df['Area Name'] = no_nulls_18_df['Area Name'].str.replace(' town', '')

no_nulls_18_df = no_nulls_18_df[['Area Name','Unemployment Rate']]
no_nulls_18_df
# Out:
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\1525602793.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_nulls_18_df['Area Name'] = no_nulls_18_df['Area Name'].str.replace(', California', '')
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\1525602793.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_nulls_18_df['Area Name'] = no_nulls_18_df['Area Name'].str.replace(' CDP', '')
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\1525602793.py:6: SettingWithCopyWarning:
# ...

# %%
unemployment19_df = pd.read_csv(unemployment19)
no_nulls_19_df = unemployment19_df.dropna(how='any')

no_nulls_19_df['Area Name'] = no_nulls_19_df['Area Name'].str.replace(', California', '')
no_nulls_19_df['Area Name'] = no_nulls_19_df['Area Name'].str.replace(' CDP', '')
no_nulls_19_df['Area Name'] = no_nulls_19_df['Area Name'].str.replace(' city', '')
no_nulls_19_df['Area Name'] = no_nulls_19_df['Area Name'].str.replace(' town', '')

no_nulls_19_df = no_nulls_19_df[['Area Name','Unemployment Rate']]
no_nulls_19_df
# Out:
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\4075009379.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_nulls_19_df['Area Name'] = no_nulls_19_df['Area Name'].str.replace(', California', '')
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\4075009379.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_nulls_19_df['Area Name'] = no_nulls_19_df['Area Name'].str.replace(' CDP', '')
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\4075009379.py:6: SettingWithCopyWarning:
# ...

# %%
unemployment20_df = pd.read_csv(unemployment20)
no_nulls_20_df = unemployment20_df.dropna(how='any')

no_nulls_20_df['Area Name'] = no_nulls_20_df['Area Name'].str.replace(', California', '')
no_nulls_20_df['Area Name'] = no_nulls_20_df['Area Name'].str.replace(' CDP', '')
no_nulls_20_df['Area Name'] = no_nulls_20_df['Area Name'].str.replace(' city', '')
no_nulls_20_df['Area Name'] = no_nulls_20_df['Area Name'].str.replace(' town', '')

no_nulls_20_df = no_nulls_20_df[['Area Name','Unemployment Rate']]
no_nulls_20_df
# Out:
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\338848086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_nulls_20_df['Area Name'] = no_nulls_20_df['Area Name'].str.replace(', California', '')
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\338848086.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_nulls_20_df['Area Name'] = no_nulls_20_df['Area Name'].str.replace(' CDP', '')
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\338848086.py:6: SettingWithCopyWarning:
# ...

# %%
unemployment21_df = pd.read_csv(unemployment21)
no_nulls_21_df = unemployment21_df.dropna(how='any')

no_nulls_21_df['Area Name'] = no_nulls_21_df['Area Name'].str.replace(', California', '')
no_nulls_21_df['Area Name'] = no_nulls_21_df['Area Name'].str.replace(' CDP', '')
no_nulls_21_df['Area Name'] = no_nulls_21_df['Area Name'].str.replace(' city', '')
no_nulls_21_df['Area Name'] = no_nulls_21_df['Area Name'].str.replace(' town', '')

no_nulls_21_df = no_nulls_21_df[['Area Name','Unemployment Rate']]
no_nulls_21_df
# Out:
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\344817069.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_nulls_21_df['Area Name'] = no_nulls_21_df['Area Name'].str.replace(', California', '')
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\344817069.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_nulls_21_df['Area Name'] = no_nulls_21_df['Area Name'].str.replace(' CDP', '')
# C:\Users\EJ-PC\AppData\Local\Temp\ipykernel_3172\344817069.py:6: SettingWithCopyWarning:
# ...

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# %%
no_nulls_18_df['Unemployment Rate'] = no_nulls_21_df['Unemployment Rate'].str.replace('%', '')
no_nulls_19_df['Unemployment Rate'] = no_nulls_21_df['Unemployment Rate'].str.replace('%', '')
no_nulls_20_df['Unemployment Rate'] = no_nulls_21_df['Unemployment Rate'].str.replace('%', '')
no_nulls_21_df['Unemployment Rate'] = no_nulls_21_df['Unemployment Rate'].str.replace('%', '')

no_nulls_18_df['Unemployment Rate'] = no_nulls_18_df['Unemployment Rate'].astype(float)
no_nulls_19_df['Unemployment Rate'] = no_nulls_19_df['Unemployment Rate'].astype(float)
no_nulls_20_df['Unemployment Rate'] = no_nulls_20_df['Unemployment Rate'].astype(float)
no_nulls_21_df['Unemployment Rate'] = no_nulls_21_df['Unemployment Rate'].astype(float)

# no_outliers_18_df = remove_outliers(no_nulls_18_df, 'Unemployment Rate')
# no_outliers_19_df = remove_outliers(no_nulls_19_df, 'Unemployment Rate')
# no_outliers_20_df = remove_outliers(no_nulls_20_df, 'Unemployment Rate')
# no_outliers_21_df = remove_outliers(no_nulls_21_df, 'Unemployment Rate')

# %%
no_nulls_18_df = no_nulls_18_df.rename(columns={'Area Name': 'City', 'Unemployment Rate': 'Unemployment Rate 18'})
no_nulls_19_df = no_nulls_19_df.rename(columns={'Area Name': 'City', 'Unemployment Rate': 'Unemployment Rate 19'})
no_nulls_20_df = no_nulls_20_df.rename(columns={'Area Name': 'City', 'Unemployment Rate': 'Unemployment Rate 20'})
no_nulls_21_df = no_nulls_21_df.rename(columns={'Area Name': 'City', 'Unemployment Rate': 'Unemployment Rate 21'})

# %%
zillow_csv = Path("csv_data/clear_ca_sfh1.csv")
zillow_df = pd.read_csv(zillow_csv)
zillow_df = zillow_df.rename(columns={
    '2015': '2015 Price',
    '2016': '2016 Price',
    '2017': '2017 Price',
    '2018': '2018 Price',
    '2019': '2019 Price',
    '2020': '2020 Price',
    '2021': '2021 Price',
})

# %%
merge_df = no_nulls_18_df.merge(zillow_df, on='City')
merge_df = no_nulls_19_df.merge(merge_df, on='City')
merge_df = no_nulls_20_df.merge(merge_df, on='City')
merge_df = no_nulls_21_df.merge(merge_df, on='City')
final_df = merge_df.dropna(how='any')
final_df
# Out:
#               City  Unemployment Rate 21  Unemployment Rate 20  \
# 0           Albany                   3.6                   3.6
# 1    Castro Valley                   3.8                   3.8
# 2       Emeryville                   5.4                   5.4
# 3         Piedmont                   6.2                   6.2
# 4      San Lorenzo                   7.2                   7.2
# ..             ...                   ...                   ...
# 394        Esparto                   3.2                   3.2
# 395        Winters                   3.0                   3.0
# 396     Marysville                   8.1                   8.1
# 397     Olivehurst                   8.1                   8.1
# 398      Wheatland                   2.6                   2.6
#
#      Unemployment Rate 19  Unemployment Rate 18  2015 Price  2016 Price  \
# 0                     3.6                   3.6    859569.9    937844.3
# ...

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Create scatter plot
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-", label=line_eq)

    # Label plot
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.xticks(rotation=45)
    plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
    plt.gcf().axes[0].xaxis.get_major_formatter().set_scientific(False)
    
    print(f"The R value is: {rvalue}")
    # Print r-squared value
    print(f"The r-squared is: {rvalue**2}")
    
    # Show plot
    plt.legend()
    
    output_path = os.path.join('unemploymentplots', f'{x_label}_v_{y_label}.png')
    plt.savefig(output_path, bbox_inches='tight')
    plt.show()

# %%
x_data = final_df['Unemployment Rate 18']
y_data = final_df['2018 Price']
# x_data = remove_outliers(x_data)
# y_data = remove_outliers(y_data)
plot_linear_regression(x_data,y_data, "Unemployment Rate 2018 (%)","2018 Price")
# Out:
# The R value is: -0.20024069937650676
# The r-squared is: 0.040096337686792556

# %%
x_data = final_df['Unemployment Rate 19']
y_data = final_df['2019 Price']
# x_data = remove_outliers(x_data)
# y_data = remove_outliers(y_data)
plot_linear_regression(x_data,y_data, "Unemployment Rate 2019 (%)","2019 Price")
# Out:
# The R value is: -0.19970513929713699
# The r-squared is: 0.03988214266168889

# %%
x_data = final_df['Unemployment Rate 20']
y_data = final_df['2020 Price']
# x_data = remove_outliers(x_data)
# y_data = remove_outliers(y_data)
plot_linear_regression(x_data,y_data, "Unemployment Rate 2020 (%)","2020 Price")
# Out:
# The R value is: -0.19967337560478438
# The r-squared is: 0.0398694569254093

# %%
x_data = final_df['Unemployment Rate 21']
y_data = final_df['2021 Price']
# x_data = remove_outliers(x_data)
# y_data = remove_outliers(y_data)
plot_linear_regression(x_data,y_data, "Unemployment Rate 2021 (%)","2021 Price")
# Out:
# The R value is: -0.20088309306269572
# The r-squared is: 0.040354017078435674

# %%
no_outliers_df = remove_outliers(final_df, 'Unemployment Rate 18')
no_outliers_df = remove_outliers(no_outliers_df, '2018 Price')

x_data = no_outliers_df['Unemployment Rate 18']
y_data = no_outliers_df['2018 Price']


plot_linear_regression(x_data,y_data, "Unemployment Rate 2018 (%) - no outliers","2018 Price  - no outliers")
# Out:
# The R value is: -0.25229960079395813
# The r-squared is: 0.06365508856079063

# %%
no_outliers_df = remove_outliers(final_df, 'Unemployment Rate 19')
no_outliers_df = remove_outliers(no_outliers_df, '2019 Price')

x_data = no_outliers_df['Unemployment Rate 19']
y_data = no_outliers_df['2019 Price']


plot_linear_regression(x_data,y_data, "Unemployment Rate 2019 (%) - no outliers","2019 Price  - no outliers")
# Out:
# The R value is: -0.258693868181638
# The r-squared is: 0.06692251743477869

# %%
no_outliers_df = remove_outliers(final_df, 'Unemployment Rate 20')
no_outliers_df = remove_outliers(no_outliers_df, '2020 Price')

x_data = no_outliers_df['Unemployment Rate 20']
y_data = no_outliers_df['2020 Price']


plot_linear_regression(x_data,y_data, "Unemployment Rate 2020 (%) - no outliers", "2020 Price  - no outliers")
# Out:
# The R value is: -0.2588870036419155
# The r-squared is: 0.06702248065468919

# %%
no_outliers_df = remove_outliers(final_df, 'Unemployment Rate 21')
no_outliers_df = remove_outliers(no_outliers_df, '2021 Price')

x_data = no_outliers_df['Unemployment Rate 21']
y_data = no_outliers_df['2021 Price']


plot_linear_regression(x_data,y_data, "Unemployment Rate 2021 (%) - no outliers", "2021 Price  - no outliers")
# Out:
# The R value is: -0.2513010239649096
# The r-squared is: 0.06315220464581207
