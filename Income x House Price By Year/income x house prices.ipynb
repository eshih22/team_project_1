# 9               13.290847
# 10              18.005477
# 11              11.369310
# 12              15.129328
# 13              13.803321
# 14              17.430372
# 15              18.717201
# 16              15.491598
# 17              16.186411
# 18              17.808906
# 19              15.467123
#
# [20 rows x 27 columns]

# %%
df_income_x_city.head(20)
# Out:
#                  City  FIPS code  Year  Total Households  Less than 10,000  \
# 0     Camp Nelson CDP          6  2015                51                 0
# 1           Campo CDP          6  2015               874                25
# 2    Camptonville CDP          6  2015                93                10
# 3           Canby CDP          6  2015                68                 0
# 4          Carmet CDP          6  2015                 7                 0
# 5   Carnelian Bay CDP          6  2015               185                20
# 6     Kings Beach CDP          6  2015              1319                47
# 7        Lincoln city          6  2015             17224               566
# 8    North Auburn CDP          6  2015              5195               349
# 9       Bluewater CDP          6  2015               103                 0
# 10        Rialto city          6  2015             25199              1178
# 11     Wrightwood CDP          6  2015              1760               198
# 12         Orcutt CDP          6  2015             10836               242
# 13     Santa Ynez CDP          6  2015              1710               101
# 14     Carmichael CDP          6  2015             26074              1402
# 15         Florin CDP          6  2015             15247               969
# 16       Vineyard CDP          6  2015              7695               311
# 17  Potter Valley CDP          6  2015               202                21
# 18      Princeton CDP          6  2015                88                 7
# 19       Proberta CDP          6  2015                81                 0
#
#     10,000 to 14,999  15,000 to 24,999  25,000 to 34,999  35,000 to 49,999  \
# 0                  0                 0                16                 0
# 1                 79               115                50               127
# 2                 17                11                10                14
# 3                  0                 0                 0                56
# 4                  0                 0                 7                 0
# 5                  5                 0                 5                25
# 6                108               258               195               288
# 7                645              1484              1362              1584
# 8                272               710               587               591
# 9                  0                25                19                20
# 10              1347              2724              2953              4101
# 11                27               230               116               254
# 12               240               692               901              1276
# 13                42                71               110               102
# 14              1535              2902              2420              3736
# 15              1437              2237              1926              2728
# 16               250               460               533               593
# 17                 5                22                13                10
# 18                 0                18                 0                23
# 19                 0                 0                42                 0
#
#     50,000 to 74,999  75,000 to 99,999  100,000 to 149,999  \
# 0                  0                15                   0
# 1                190                79                 147
# 2                 15                 0                  13
# 3                  0                 0                  12
# 4                  0                 0                   0
# 5                 24                26                  52
# 6                182                70                 114
# 7               3373              2764                3466
# 8                904               678                 686
# 9                 19                10                   5
# 10              5248              3941                2516
# 11               314               212                 204
# 12              2266              1465                2160
# 13               220               204                 319
# 14              4233              3453                3488
# 15              2631              1601                1103
# 16              1460              1348                1606
# 17                23                40                  64
# 18                14                19                   0
# 19                15                 0                  24
#
#     150,000 to 199,999  200,000 or more
# 0                   20                0
# 1                   62                0
# 2                    0                3
# 3                    0                0
# 4                    0                0
# 5                   17               11
# 6                   35               22
# 7                 1376              604
# 8                  258              160
# 9                    0                5
# 10                 820              371
# 11                 119               86
# 12                 943              651
# 13                 308              233
# 14                1351             1554
# 15                 330              285
# 16                 756              378
# 17                   4                0
# 18                   7                0
# 19                   0                0

# %%
df_income_x_city['City'] = df_income_x_city['City'].str.rstrip(" CDP")

# %%
df_income_x_city.head(20)
# Out:
#              City  FIPS code  Year  Total Households  Less than 10,000  \
# 0     Camp Nelson          6  2015                51                 0
# 1           Campo          6  2015               874                25
# 2    Camptonville          6  2015                93                10
# 3           Canby          6  2015                68                 0
# 4          Carmet          6  2015                 7                 0
# 5   Carnelian Bay          6  2015               185                20
# 6     Kings Beach          6  2015              1319                47
# 7    Lincoln city          6  2015             17224               566
# 8    North Auburn          6  2015              5195               349
# 9       Bluewater          6  2015               103                 0
# 10    Rialto city          6  2015             25199              1178
# 11     Wrightwood          6  2015              1760               198
# 12         Orcutt          6  2015             10836               242
# 13     Santa Ynez          6  2015              1710               101
# 14     Carmichael          6  2015             26074              1402
# 15         Florin          6  2015             15247               969
# 16       Vineyard          6  2015              7695               311
# 17  Potter Valley          6  2015               202                21
# 18      Princeton          6  2015                88                 7
# 19       Proberta          6  2015                81                 0
#
#     10,000 to 14,999  15,000 to 24,999  25,000 to 34,999  35,000 to 49,999  \
# 0                  0                 0                16                 0
# 1                 79               115                50               127
# 2                 17                11                10                14
# 3                  0                 0                 0                56
# 4                  0                 0                 7                 0
# 5                  5                 0                 5                25
# 6                108               258               195               288
# 7                645              1484              1362              1584
# 8                272               710               587               591
# 9                  0                25                19                20
# 10              1347              2724              2953              4101
# 11                27               230               116               254
# 12               240               692               901              1276
# 13                42                71               110               102
# 14              1535              2902              2420              3736
# 15              1437              2237              1926              2728
# 16               250               460               533               593
# 17                 5                22                13                10
# 18                 0                18                 0                23
# 19                 0                 0                42                 0
#
#     50,000 to 74,999  75,000 to 99,999  100,000 to 149,999  \
# 0                  0                15                   0
# 1                190                79                 147
# 2                 15                 0                  13
# 3                  0                 0                  12
# 4                  0                 0                   0
# 5                 24                26                  52
# 6                182                70                 114
# 7               3373              2764                3466
# 8                904               678                 686
# 9                 19                10                   5
# 10              5248              3941                2516
# 11               314               212                 204
# 12              2266              1465                2160
# 13               220               204                 319
# 14              4233              3453                3488
# 15              2631              1601                1103
# 16              1460              1348                1606
# 17                23                40                  64
# 18                14                19                   0
# 19                15                 0                  24
#
#     150,000 to 199,999  200,000 or more
# 0                   20                0
# 1                   62                0
# 2                    0                3
# 3                    0                0
# 4                    0                0
# 5                   17               11
# 6                   35               22
# 7                 1376              604
# 8                  258              160
# 9                    0                5
# 10                 820              371
# 11                 119               86
# 12                 943              651
# 13                 308              233
# 14                1351             1554
# 15                 330              285
# 16                 756              378
# 17                   4                0
# 18                   7                0
# 19                   0                0

# %%
list(df_income_x_city.columns)
# Out:
# ['City',
#  'FIPS code',
#  'Year',
#  'Total Households',
#  'Less than 10,000',
#  '10,000 to 14,999',
#  '15,000 to 24,999',
#  '25,000 to 34,999',
#  '35,000 to 49,999',
#  '50,000 to 74,999',
#  '75,000 to 99,999',
#  '100,000 to 149,999',
#  '150,000 to 199,999',
#  '200,000 or more']

# %%
income_mapping = {
    'Less than 10,000': 10000,
    '10,000 to 14,999': 14999,
    '15,000 to 24,999': 24999,
    '25,000 to 34,999': 34999,
    '35,000 to 49,999': 49999,
    '50,000 to 74,999': 74999,
    '75,000 to 99,999': 99999,
    '100,000 to 149,999': 149999,
    '150,000 to 199,999': 199999,
    '200,000 or more': 300000
}

pop_columns = ['Less than 10,000', '10,000 to 14,999', '15,000 to 24,999', '25,000 to 34,999',
               '35,000 to 49,999', '50,000 to 74,999', '75,000 to 99,999', '100,000 to 149,999',
               '150,000 to 199,999', '200,000 or more']

income_columns = ['Less than 10,000', '10,000 to 14,999', '15,000 to 24,999', '25,000 to 34,999',
                   '35,000 to 49,999', '50,000 to 74,999', '75,000 to 99,999', '100,000 to 149,999',
                   '150,000 to 199,999', '200,000 or more']

df_income_x_city['average_income'] = df_income_x_city.apply(lambda row: sum(row[pop] * income_mapping[inc] for pop, inc in zip(pop_columns, income_columns)) / row['Total Households'] if row['Total Households'] != 0 else 0, axis=1)

df_income_x_city[['City', 'average_income']]
# Out:
#                    City  average_income
# 0           Camp Nelson   118822.529412
# 1                 Campo    78957.838673
# 2          Camptonville    60805.591398
# 3                 Canby    67646.058824
# 4                Carmet    34999.000000
# ...                 ...             ...
# 10825        Yreka city    75851.110592
# 10826    Yuba City city    99189.648816
# 10827      Yucaipa city   109633.693686
# 10828  Yucca Valley tow    87761.423602
# 10829           Zayante   163111.157343
#
# [10830 rows x 2 columns]

# %%
df_pivot = df_income_x_city.pivot(index='City', columns='Year', values='average_income')

df_pivot.columns = [f'Average Income {year}' for year in df_pivot.columns]

df_pivot.reset_index(inplace=True)

df_pivot.head()
# Out:
#              City  Average Income 2015  Average Income 2016  \
# 0  Acalanes Ridge        187655.249377        196827.700831
# 1          Acampo        180394.010526        181600.376404
# 2           Acton        120401.481197        122456.406760
# 3   Adelanto city         48302.341438         46517.050056
# 4            Adin         68332.333333         76051.631579
#
#    Average Income 2017  Average Income 2018  Average Income 2019  \
# 0        202278.190164        184842.637631        154487.185366
# 1        193414.557377        188513.855072        129089.909091
# 2        123197.932216        134086.172853        135585.512771
# 3         54601.565460         59172.705445         69938.656660
# 4         61732.333333         75594.238095         75575.923077
#
#    Average Income 2020  Average Income 2021
# 0        163735.017241        196122.166667
# 1         73319.610687         49677.899083
# 2        135715.167183        143259.751787
# 3         73755.067587         79450.019406
# 4         57390.304348         45242.902439

# %%
merged_df = pd.merge(df_pop_price, df_pivot, on='City', how='inner')

income_columns = [f'Average Income {year}' for year in range(2015, 2022)]
price_columns = [f'{year} Price' for year in range(2015, 2022)]

years = []
correlation_coefficients = []

for income_col, price_col in zip(income_columns, price_columns):
    years.append(income_col[-4:])
    correlation_coefficients.append(merged_df[income_col].corr(merged_df[price_col]))

correlation_results = pd.DataFrame({'Year': years, 'Correlation Coefficient': correlation_coefficients})

print(correlation_results)
# Out:
#    Year  Correlation Coefficient
# 0  2015                 0.673478
# 1  2016                 0.652884
# 2  2017                 0.655709
# 3  2018                 0.661219
# 4  2019                 0.657101
# 5  2020                 0.648252
# 6  2021                 0.621657

# %%
import matplotlib.pyplot as plt

plt.plot(correlation_results['Year'], correlation_results['Correlation Coefficient'], marker='o', linestyle='-')
plt.title('Correlation Coefficients Over the Years')
plt.xlabel('Year')
plt.ylim((0.6,0.7))
plt.ylabel('Correlation Coefficient')
plt.grid(True)
plt.show()

# %%
income_categories = ['Less than 10,000', '10,000 to 14,999', '15,000 to 24,999', '25,000 to 34,999',
                     '35,000 to 49,999', '50,000 to 74,999', '75,000 to 99,999', '100,000 to 149,999',
                     '150,000 to 199,999', '200,000 or more']

grouped_by_year = df_income_x_city.groupby('Year')[income_categories].sum()

grouped_by_year.plot(kind='bar', stacked=True)
plt.title('Total Populations by Income Category Over the Years')
plt.xlabel('Year')
plt.ylabel('Total Population')
plt.legend(title='Income Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
income_categories = ['Less than 10,000', '10,000 to 14,999', '15,000 to 24,999', '25,000 to 34,999',
                     '35,000 to 49,999', '50,000 to 74,999', '75,000 to 99,999', '100,000 to 149,999',
                     '150,000 to 199,999', '200,000 or more']


for year in df_income_x_city['Year'].unique():
    df_year = df_income_x_city[df_income_x_city['Year'] == year]

    plt.figure(figsize=(10, 6))
    plt.bar(income_categories, df_year[income_categories].iloc[0], color='skyblue')
    plt.title(f'Total Populations by Income Category - {year}')
    plt.xlabel('Income Category')
    plt.ylabel('Total Population')
    
    plt.xticks(rotation=270)
    
    plt.show()

# %%
import re
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
for year_col in df_pivot.columns[1:]:
    year = re.search(r'\d{4}', year_col).group()  # Extract the year from the column name
    
    plt.figure(figsize=(10, 7))
    
    # Extract data for the specific year
    x_city_data = df_income_x_city[df_income_x_city['Year'] == int(year)].sort_values('City')
    y_city_data = merged_df[merged_df[f'Average Income {year}'].notnull()].sort_values('City')
    
    # Ensure both x and y have the same set of cities
    common_cities = set(x_city_data['City']).intersection(y_city_data['City'])
    
    x = x_city_data[x_city_data['City'].isin(common_cities)]['average_income']
    y = y_city_data[y_city_data['City'].isin(common_cities)][f'{year} Price'] 
    
    plt.scatter(x, y, alpha=0.5, edgecolors="w", linewidth=0.5)
    
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    regression_line = slope * x + intercept
    
    plt.plot(x, regression_line, color='red', label='Linear Regression')
    
    plt.title(f'Average Income vs Average House Price - {year}')
    plt.xlabel('Average Income per City')
    plt.ylabel(f'Average House Price - {year}')
    
    """# Show city names on the plot
    for i, city in enumerate(x_city_data[x_city_data['City'].isin(common_cities)]['City']):
        plt.text(x.iloc[i], y.iloc[i], city, fontsize=8, ha='right', va='bottom')"""
    
    # Show linear regression formula in the subtitle
    formula_text = f'House Price = {intercept:.2f} + {slope:.2f} * Income'
    plt.suptitle(formula_text, x=0.5, y=0.96, ha='center', fontsize=12, color='green')
    
    plt.grid(True)
    plt.tight_layout()  # Adjust layout to prevent overlapping
    plt.show()
