# %%
import hvplot.pandas
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime
import requests
import json
import panel as pn
from math import radians, cos, sin, asin, sqrt
from scipy.stats import linregress

from api_key import geoapify_key


#import csv files from zillow data
sfh_data = Path("zillow data set/zillow_sfr_data.csv")
sfh_data_df = pd.read_csv(sfh_data)

#Using loc function to get the data set only for CA
ca_sfh_df = sfh_data_df.loc[sfh_data_df["State"] == "CA"]
ca_sfh_df
# Out:
#        RegionID  SizeRank           RegionName RegionType StateName State  \
# 1         12447         1          Los Angeles       city        CA    CA
# 8         54296         8            San Diego       city        CA    CA
# 11        33839        11             San Jose       city        CA    CA
# 17        20330        17        San Francisco       city        CA    CA
# 28        20288        28           Sacramento       city        CA    CA
# ...         ...       ...                  ...        ...       ...   ...
# 21430     12132     28683         Johannesburg       city        CA    CA
# 21475     23633     28683          Bear Valley       city        CA    CA
# 21476    396499     28683        Plumas Eureka       city        CA    CA
# 21563    395428     28683  Little Grass Valley       city        CA    CA
# 21587     47855     30116        Stirling City       city        CA    CA
#
#                                       Metro             CountyName  \
# ...

# %%
print(ca_sfh_df.columns)
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'CountyName', '1/31/2000', '2/29/2000',
#        ...
#        '1/31/2023', '2/28/2023', '3/31/2023', '4/30/2023', '5/31/2023',
#        '6/30/2023', '7/31/2023', '8/31/2023', '9/30/2023', '10/31/2023'],
#       dtype='object', length=294)

# %%
#Delete unused and duplicated columns
ca_sfh_df = ca_sfh_df.drop(["RegionID","SizeRank","RegionType","StateName","Metro","State","CountyName",], axis=1)
#filter data set to show data from 2015 to 2021
ca_sfh_df = ca_sfh_df.drop(ca_sfh_df.loc[:,"1/31/2000":"12/31/2014"].columns, axis=1)
ca_sfh_df = ca_sfh_df.drop(ca_sfh_df.loc[:,"1/31/2022":"10/31/2023"].columns, axis=1)
ca_sfh_df = ca_sfh_df.rename(columns={"RegionName":"City"})
ca_sfh_df
# Out:
#                       City     1/31/2015     2/28/2015     3/31/2015  \
# 1              Los Angeles  5.291565e+05  5.310011e+05  5.303974e+05
# 8                San Diego  5.430120e+05  5.471201e+05  5.508658e+05
# 11                San Jose  7.189839e+05  7.270660e+05  7.314359e+05
# 17           San Francisco  1.017415e+06  1.034108e+06  1.050345e+06
# 28              Sacramento  2.338120e+05  2.356985e+05  2.376231e+05
# ...                    ...           ...           ...           ...
# 21430         Johannesburg           NaN           NaN           NaN
# 21475          Bear Valley           NaN           NaN           NaN
# 21476        Plumas Eureka  2.309197e+05  2.303502e+05  2.296174e+05
# 21563  Little Grass Valley           NaN           NaN           NaN
# 21587        Stirling City  5.938531e+04  6.031800e+04  6.105675e+04
#
#           4/30/2015     5/31/2015     6/30/2015     7/31/2015     8/31/2015  \
# ...

# %%
#Caluclate the mean and grab the city & Mean of the year column
years = range(2015,2022)
year_mean = []
for year in years:
    start = f"1/31/{year}"
    end = f"12/31/{year}"
    mean = ca_sfh_df.loc[:, start:end].mean(axis=1)
    year_mean.append((year, round(mean,1)))

for year, mean in year_mean:
    ca_sfh_df[str((year))] = mean
    
selected_columns = ["City"] + [str(year) for year in years]
clear_ca_sfh_df = ca_sfh_df[selected_columns]

clear_ca_sfh_df = clear_ca_sfh_df.sort_values(by="City")
clear_ca_sfh_df = clear_ca_sfh_df.reset_index(drop=True)
clear_ca_sfh_df.dropna(how='any', inplace=True)
clear_ca_sfh_df
# Out:
#              City      2015      2016      2017       2018       2019  \
# 0          Acampo  411290.3  457113.1  499479.8   549449.1   576265.3
# 1           Acton  429758.9  449873.7  483729.3   536849.0   565247.3
# 2        Adelanto  151547.4  163231.4  185646.1   215282.2   229858.4
# 3            Adin  151136.3  163947.3  175406.9   186325.1   191057.7
# 4    Agoura Hills  726644.3  729300.6  782420.1   849757.7   857486.5
# ..            ...       ...       ...       ...        ...        ...
# 958    Yountville  867632.5  930751.6  985898.6  1040493.4  1078248.0
# 959         Yreka  147052.4  155893.3  163423.5   174930.9   190187.6
# 960     Yuba City  225099.8  243232.4  270577.0   295807.7   310524.3
# 961       Yucaipa  286070.9  302006.7  332697.6   369420.6   376584.5
# 962  Yucca Valley  133268.8  142233.7  162087.2   195388.9   205148.5
#
#           2020       2021
# 0     577935.7   706673.6
# 1     591931.2   698957.6
# 2     245152.2   300593.3
# ...

# %%
lat = []
lng = []
for city in clear_ca_sfh_df["City"]:
    url = f"https://api.geoapify.com/v1/geocode/search?text={city}&country=United%20States%20of%20America&state=CA&apiKey={geoapify_key}"
    response = requests.get(url).json()
    
    lat.append(response["features"][0]["properties"]["lat"])
    lng.append(response["features"][0]["properties"]["lon"])
    
clear_ca_sfh_df["lat"] = lat
clear_ca_sfh_df["lng"] = lng
clear_ca_sfh_df.head()
# Out:
#            City      2015      2016      2017      2018      2019      2020  \
# 0        Acampo  411290.3  457113.1  499479.8  549449.1  576265.3  577935.7
# 1         Acton  429758.9  449873.7  483729.3  536849.0  565247.3  591931.2
# 2      Adelanto  151547.4  163231.4  185646.1  215282.2  229858.4  245152.2
# 3          Adin  151136.3  163947.3  175406.9  186325.1  191057.7  193622.4
# 4  Agoura Hills  726644.3  729300.6  782420.1  849757.7  857486.5  897807.2
#
#         2021        lat         lng
# 0   706673.6  38.174640 -121.278559
# 1   698957.6  34.469994 -118.196742
# 2   300593.3  34.582770 -117.409215
# 3   229474.8  41.194838 -120.944226
# 4  1046212.4  34.147910 -118.765704

# %%
#map_plot for 2015
map_plot = clear_ca_sfh_df.hvplot.points(
    "lng",
    "lat",
    geo=True,
    tiles="OSM",
    size="2015",
    frame_width=500, 
    frame_height=500,
    color="City",
    scale=0.008,
    xlim=(-124.48, -114.13),
    ylim=(32.53, 42.01)
)

map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (City,2015)

# %%
#map_plot for 2016
map_plot = clear_ca_sfh_df.hvplot.points(
    "lng",
    "lat",
    geo=True,
    tiles="OSM",
    size="2016",
    frame_width=500, 
    frame_height=500,
    color="City",
    scale=0.01,
    xlim=(-124.48, -114.13),
    ylim=(32.53, 42.01)
)


map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (City,2016)

# %%
#map_plot for 2017
map_plot = clear_ca_sfh_df.hvplot.points(
    "lng",
    "lat",
    geo=True,
    tiles="OSM",
    size="2017",
    frame_width=500, 
    frame_height=500,
    color="City",
    scale=0.01,
    xlim=(-124.48, -114.13),
    ylim=(32.53, 42.01)
)


map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (City,2017)

# %%
#map_plot for 2018
map_plot = clear_ca_sfh_df.hvplot.points(
    "lng",
    "lat",
    geo=True,
    tiles="OSM",
    size="2017",
    frame_width=500, 
    frame_height=500,
    color="City",
    scale=0.01,
    xlim=(-124.48, -114),
    ylim=(31, 43)
)


map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (City,2017)

# %%
#map_plot for 2019
map_plot = clear_ca_sfh_df.hvplot.points(
    "lng",
    "lat",
    geo=True,
    tiles="OSM",
    size="2019",
    frame_width=500, 
    frame_height=500,
    color="City",
    scale=0.01,
    xlim=(-124.48, -114.13),
    ylim=(32.53, 42.01)
)

map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (City,2019)

# %%
#map_plot for 2020
map_plot = clear_ca_sfh_df.hvplot.points(
    "lng",
    "lat",
    geo=True,
    tiles="OSM",
    size="2020",
    frame_width=500, 
    frame_height=500,
    color="City",
    scale=0.01,
    xlim=(-124.48, -114.13),
    ylim=(32.53, 42.01)
)

map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (City,2020)

# %%
#map_plot for 2021
map_plot = clear_ca_sfh_df.hvplot.points(
    "lng",
    "lat",
    geo=True,
    tiles="OSM",
    size="2021",
    frame_width=500, 
    frame_height=500,
    color="City",
    scale=0.01,
    xlim=(-124.48, -114.13),
    ylim=(32.53, 42.01)
)

map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (City,2021)

# %%
#Distance calculation
def haversine(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlat = lat2 - lat1 
    dlon = lon2 - lon1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 3956 
    return c * r

msa_cities = [
    "Anaheim", "Santa Ana", "Irvine", "Bakersfield", "Chico", "El Centro", 
    "Fresno", "Hanford", "Corcoran", "Los Angeles", "Long Beach", "Glendale", 
    "Madera", "Merced", "Modesto", "Napa", "Oakland", "Hayward", "Berkeley", 
    "Oxnard", "Thousand Oaks", "Ventura", "Redding", "Riverside", "San Bernardino", 
    "Ontario", "Sacramento", "Roseville", "Arden-Arcade", "Salinas", "San Diego", 
    "Carlsbad", "San Francisco", "Redwood City", "South San Francisco", "San Jose", 
    "Sunnyvale", "Santa Clara", "San Luis Obispo", "Paso Robles", "Arroyo Grande", 
    "San Rafael", "Santa Cruz", "Watsonville", "Santa Maria", "Santa Barbara", 
    "Santa Rosa", "Stockton", "Lodi", "Vallejo", "Fairfield", "Visalia", "Porterville", 
    "Yuba City"
]


major_cities_df = clear_ca_sfh_df[clear_ca_sfh_df['City'].isin(msa_cities)]

for index, row in clear_ca_sfh_df.iterrows():
    city_lat = row['lat']
    city_lng = row['lng']
    min_distance = float('inf')
    closest_major_city = None

    for _, major_city_row in major_cities_df.iterrows():
        major_city = major_city_row['City']
        major_city_lat = major_city_row['lat']
        major_city_lng = major_city_row['lng']

        distance = haversine(city_lat, city_lng, major_city_lat, major_city_lng)
        if distance < min_distance:
            min_distance = distance
            closest_major_city = major_city

    clear_ca_sfh_df.at[index, 'Closest Major City'] = closest_major_city
    clear_ca_sfh_df.at[index, "Distance to Closest Major City(Miles)"] = round(min_distance,1)

clear_ca_sfh_df.head()
# Out:
#            City      2015      2016      2017      2018      2019      2020  \
# 0        Acampo  411290.3  457113.1  499479.8  549449.1  576265.3  577935.7
# 1         Acton  429758.9  449873.7  483729.3  536849.0  565247.3  591931.2
# 2      Adelanto  151547.4  163231.4  185646.1  215282.2  229858.4  245152.2
# 3          Adin  151136.3  163947.3  175406.9  186325.1  191057.7  193622.4
# 4  Agoura Hills  726644.3  729300.6  782420.1  849757.7  857486.5  897807.2
#
#         2021        lat         lng Closest Major City  \
# 0   706673.6  38.174640 -121.278559               Lodi
# 1   698957.6  34.469994 -118.196742           Glendale
# 2   300593.3  34.582770 -117.409215     San Bernardino
# 3   229474.8  41.194838 -120.944226            Redding
# 4  1046212.4  34.147910 -118.765704      Thousand Oaks
#
#    Distance to Closest Major City(Miles)
# 0                                    8.3
# 1                                   22.5
# 2                                   33.5
# ...

# %%
def plot_linear_regression(x_values, y_values, x_label, y_label):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Create scatter plot
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-", label=line_eq)

    # Label plot
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.xticks(rotation=45)
    plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
    plt.gcf().axes[0].xaxis.get_major_formatter().set_scientific(False)
    
    print(f"The R value is: {rvalue}")
    # Print r-squared value
    print(f"The r-squared is: {rvalue**2}")
    
    # Show plot
    plt.legend()
    
    #output_path = os.path.join('plots', f'{x_label}_v_{y_label}.png')
    #plt.savefig(output_path)
    plt.show()

# %%
x_data = clear_ca_sfh_df["Distance to Closest Major City(Miles)"]
y_data = clear_ca_sfh_df["2015"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2015 House Mean Price")
# Out:
# The R value is: -0.12895577662409555
# The r-squared is: 0.01662959232472363

# %%
x_data = clear_ca_sfh_df["Distance to Closest Major City(Miles)"]
y_data = clear_ca_sfh_df["2016"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2016 House Mean Price")
# Out:
# The R value is: -0.12982853987865167
# The r-squared is: 0.01685544976702265

# %%
x_data = clear_ca_sfh_df["Distance to Closest Major City(Miles)"]
y_data = clear_ca_sfh_df["2017"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2017 House Mean Price")
# Out:
# The R value is: -0.13276983288730287
# The r-squared is: 0.017627828524922333

# %%
x_data = clear_ca_sfh_df["Distance to Closest Major City(Miles)"]
y_data = clear_ca_sfh_df["2018"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2018 House Mean Price")
# Out:
# The R value is: -0.13272321876944823
# The r-squared is: 0.017615452800522815

# %%
x_data = clear_ca_sfh_df["Distance to Closest Major City(Miles)"]
y_data = clear_ca_sfh_df["2019"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2019 House Mean Price")
# Out:
# The R value is: -0.1319871639961342
# The r-squared is: 0.017420611459742424

# %%
x_data = clear_ca_sfh_df["Distance to Closest Major City(Miles)"]
y_data = clear_ca_sfh_df["2020"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2020 House Mean Price")
# Out:
# The R value is: -0.13355616377726143
# The r-squared is: 0.017837248882898678

# %%
x_data = clear_ca_sfh_df["Distance to Closest Major City(Miles)"]
y_data = clear_ca_sfh_df["2021"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2021 House Mean Price")
# Out:
# The R value is: -0.13233563281848257
# The r-squared is: 0.01751271971346824

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# %%
clear_no_outliers_df = remove_outliers(clear_ca_sfh_df, 'Distance to Closest Major City(Miles)')
clear_no_outliers_df = remove_outliers(clear_no_outliers_df, '2015')

x_data = clear_no_outliers_df["Distance to Closest Major City(Miles)"]
y_data = clear_no_outliers_df["2015"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2015 House Mean Price")
plt.savefig("2015.png")

plt.show()
# Out:
# The R value is: -0.38960153525807484
# The r-squared is: 0.15178935627544893

# %%
clear_no_outliers_df = remove_outliers(clear_ca_sfh_df, 'Distance to Closest Major City(Miles)')
clear_no_outliers_df = remove_outliers(clear_no_outliers_df, '2016')

x_data = clear_no_outliers_df["Distance to Closest Major City(Miles)"]
y_data = clear_no_outliers_df["2016"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2016 House Mean Price")
# Out:
# The R value is: -0.3894987529401743
# The r-squared is: 0.15170927854195093

# %%
clear_no_outliers_df = remove_outliers(clear_ca_sfh_df, 'Distance to Closest Major City(Miles)')
clear_no_outliers_df = remove_outliers(clear_no_outliers_df, '2017')

x_data = clear_no_outliers_df["Distance to Closest Major City(Miles)"]
y_data = clear_no_outliers_df["2017"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2017 House Mean Price")
# Out:
# The R value is: -0.4014034703294423
# The r-squared is: 0.16112474599251947

# %%
clear_no_outliers_df = remove_outliers(clear_ca_sfh_df, 'Distance to Closest Major City(Miles)')
clear_no_outliers_df = remove_outliers(clear_no_outliers_df, '2018')

x_data = clear_no_outliers_df["Distance to Closest Major City(Miles)"]
y_data = clear_no_outliers_df["2018"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2018 House Mean Price")
# Out:
# The R value is: -0.40298236323400755
# The r-squared is: 0.1623947850776656

# %%
clear_no_outliers_df = remove_outliers(clear_ca_sfh_df, 'Distance to Closest Major City(Miles)')
clear_no_outliers_df = remove_outliers(clear_no_outliers_df, '2019')

x_data = clear_no_outliers_df["Distance to Closest Major City(Miles)"]
y_data = clear_no_outliers_df["2019"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2019 House Mean Price")
# Out:
# The R value is: -0.4076526936086541
# The r-squared is: 0.1661807186063912

# %%
clear_no_outliers_df = remove_outliers(clear_ca_sfh_df, 'Distance to Closest Major City(Miles)')
clear_no_outliers_df = remove_outliers(clear_no_outliers_df, '2020')

x_data = clear_no_outliers_df["Distance to Closest Major City(Miles)"]
y_data = clear_no_outliers_df["2020"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2020 House Mean Price")
# Out:
# The R value is: -0.4121296957882959
# The r-squared is: 0.16985088615055333

# %%
clear_no_outliers_df = remove_outliers(clear_ca_sfh_df, 'Distance to Closest Major City(Miles)')
clear_no_outliers_df = remove_outliers(clear_no_outliers_df, '2021')

x_data = clear_no_outliers_df["Distance to Closest Major City(Miles)"]
y_data = clear_no_outliers_df["2021"]
plot_linear_regression(x_data, y_data, "Distance to Closest Major City(Miles)","2021 House Mean Price")
# Out:
# The R value is: -0.4014134823675137
# The r-squared is: 0.16113278382641422
